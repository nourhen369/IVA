# %%
test_image_retrieval("/content/drive/MyDrive/DeepCBIR_Dataset/test_set/dinosaurs/400.jpg")
# Out:
# Top images similaires pour /content/drive/MyDrive/DeepCBIR_Dataset/test_set/dinosaurs/400.jpg : ['/content/drive/MyDrive/DeepCBIR_Dataset/training_set/dinosaurs/474.jpg', '/content/drive/MyDrive/DeepCBIR_Dataset/training_set/dinosaurs/460.jpg', '/content/drive/MyDrive/DeepCBIR_Dataset/training_set/dinosaurs/420.jpg', '/content/drive/MyDrive/DeepCBIR_Dataset/training_set/dinosaurs/498.jpg', '/content/drive/MyDrive/DeepCBIR_Dataset/training_set/dinosaurs/437.jpg']

# %%
test_image_retrieval("/content/drive/MyDrive/DeepCBIR_Dataset/test_set/elephants/504.jpg")
# Out:
# Top images similaires pour /content/drive/MyDrive/DeepCBIR_Dataset/test_set/elephants/504.jpg : ['/content/drive/MyDrive/DeepCBIR_Dataset/training_set/elephants/536.jpg', '/content/drive/MyDrive/DeepCBIR_Dataset/training_set/bus/347.jpg', '/content/drive/MyDrive/DeepCBIR_Dataset/training_set/elephants/594.jpg', '/content/drive/MyDrive/DeepCBIR_Dataset/training_set/bus/365.jpg', '/content/drive/MyDrive/DeepCBIR_Dataset/training_set/horses/741.jpg']

# %%
test_image_retrieval("/content/drive/MyDrive/DeepCBIR_Dataset/test_set/flowers/603.jpg")
# Out:
# Top images similaires pour /content/drive/MyDrive/DeepCBIR_Dataset/test_set/flowers/603.jpg : ['/content/drive/MyDrive/DeepCBIR_Dataset/training_set/flowers/626.jpg', '/content/drive/MyDrive/DeepCBIR_Dataset/training_set/flowers/619.jpg', '/content/drive/MyDrive/DeepCBIR_Dataset/training_set/flowers/618.jpg', '/content/drive/MyDrive/DeepCBIR_Dataset/training_set/flowers/650.jpg', '/content/drive/MyDrive/DeepCBIR_Dataset/training_set/flowers/657.jpg']

# %%
test_image_retrieval("/content/drive/MyDrive/DeepCBIR_Dataset/test_set/beaches/100.jpg")
# Out:
# Top images similaires pour /content/drive/MyDrive/DeepCBIR_Dataset/test_set/beaches/100.jpg : ['/content/drive/MyDrive/DeepCBIR_Dataset/training_set/horses/756.jpg', '/content/drive/MyDrive/DeepCBIR_Dataset/training_set/peolpe_and_villages_in_Africa/88.jpg', '/content/drive/MyDrive/DeepCBIR_Dataset/training_set/horses/755.jpg', '/content/drive/MyDrive/DeepCBIR_Dataset/training_set/elephants/570.jpg', '/content/drive/MyDrive/DeepCBIR_Dataset/training_set/elephants/563.jpg']

# %%
test_image_retrieval("/content/drive/MyDrive/DeepCBIR_Dataset/test_set/foods/902.jpg")
# Out:
# Top images similaires pour /content/drive/MyDrive/DeepCBIR_Dataset/test_set/foods/902.jpg : ['/content/drive/MyDrive/DeepCBIR_Dataset/training_set/foods/950.jpg', '/content/drive/MyDrive/DeepCBIR_Dataset/training_set/foods/928.jpg', '/content/drive/MyDrive/DeepCBIR_Dataset/training_set/beaches/196.jpg', '/content/drive/MyDrive/DeepCBIR_Dataset/training_set/monuments/260.jpg', '/content/drive/MyDrive/DeepCBIR_Dataset/training_set/horses/715.jpg']
